# %% [markdown]
# <a href="https://colab.research.google.com/github/rajnish80130/session-27-import-and-export-data-and-data-gathering-through-api/blob/main/Session_27_Data_Extract_through_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
response.json()

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     174.665
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     137.888
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      93.397
# 3  The true story of how businessman Oskar Schind...   1993-12-15      91.073
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      48.840
#
#    vote_average  vote_count
# 0         8.709       19075
# 1         8.700       25070
# 2         8.590       11510
# 3         8.572       14858
# 4         8.547        4295

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,451):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df = df.append(temp_df,ignore_index=True)
# Out:
# <ipython-input-12-fa2043f79e6b>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-12-fa2043f79e6b>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-12-fa2043f79e6b>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# <ipython-input-12-fa2043f79e6b>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#          id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 8989  12142            Alone in the Dark
# 8990   5491            Battlefield Earth
# 8991  11059            House of the Dead
# 8992  14164         Dragonball Evolution
# 8993  40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %%
df.to_csv("updated_top_movies_tmbd.csv")
